# %% [markdown]
# # Softmax классификатор
#
# *Заполните этот блокнот, выполните код и защитите результаты. Полностью заполненный блокнот необходимо сохранить в электронном виде, передав его копию преподавателю, ведущему занятия.
#
# Это задание аналогично заданию исследования SVM классификатора.
# В этом упражнении вы должны будете:
#
# - реализовать полностью векторизованную **функцию потерь** для Sоftmax классификатора
# - реализовать полностью векторизованное выражение для её **аналитического градиента**
# - **проверить свою реализацию** с помощью численного градиента
# - использовать валидационное множество для подбора **скорости обучения и коэффициента регуляризации**
# - **оптимизировать** функцию потерь с помощью алгоритма **SGD**
# - **визуализировать** окончательные обученные веса классификатора
#
# Этот блокнот является адаптированной версией аналогичного курса [Стэнфордского университета](http://vision.stanford.edu/teaching/cs231n/index.html)

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

#from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Для перезагрузки внешних модули python;
# см. http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Загружает набор данных CIFAR-10 с диска и выполняет его предварительную обработку для 
    линейной классификации. Функция выполняет те же действия, которые выполнялись при
    подготовке данных для  SVM классификатора.Но все действия собраны в одной функции.
       
    """
    # Загрузка базы CIFAR-10.
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # выборка данных
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Предобработка: реформатирование изображений в векторы
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Нормализация данных: вычитание среднего изображения
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # добавление смещения и преобразование в столбцы
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev



# Очистка переменных для предотвращения повторной загрузки данных (что может вызвать проблемы с памятью)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass


# Вызов функции, определенной выше для получения данных
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax классификатор
#
# Ваш код для этого раздела необходимо помещать в файл **cs231n/classifiers/softmax.py**.

# %%
# Сначала реализуем наивную функцию потерь softmax с вложенными циклами.
# Откройте файл cs231n/classifiers/softmax.py и реализуйте функцию 
# softmax_loss_naive.



from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Создание случайной весовой матрицы и использование ее для вычисления потерь (loss).
W = np.random.randn(3073, 10) * 0.00000001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# Проверка здравого смысла -  потери должны быть близкими к -log (0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.302587
# sanity check: 2.302585

# %% [markdown]
# ## Вопрос 1:
#
# Почему мы ожидаем, что потери будут близки к -log (0.1)? Объясните кратко. **
#
# **Ваш ответ:** *Отвечайте здесь*

# %%
# Завершите реализацию softmax_loss_naive и реализуйте (наивную)
# версию вычисления градиента, которая использует вложенные циклы.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# Как и для SVM, используйте проверку числового градиента как инструмент отладки.
# Числовой градиент должен быть близок к аналитическому градиенту.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# Аналогично случаю SVM, выполните еще одну проверку градиента с регуляризацией
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.981382 analytic: -0.981383, relative error: 1.867578e-08
# numerical: -0.448615 analytic: -0.448615, relative error: 7.638392e-08
# numerical: -0.568245 analytic: -0.568245, relative error: 3.525029e-08
# numerical: -1.949097 analytic: -1.949097, relative error: 1.835607e-08
# numerical: -1.074164 analytic: -1.074164, relative error: 1.102217e-08
# numerical: -0.028110 analytic: -0.028110, relative error: 6.347276e-07
# numerical: -6.761143 analytic: -6.761143, relative error: 9.806592e-09
# numerical: 1.385874 analytic: 1.385874, relative error: 5.015364e-08
# numerical: -1.128774 analytic: -1.128774, relative error: 1.974321e-08
# numerical: -2.913122 analytic: -2.913122, relative error: 6.178331e-09
# numerical: -0.002284 analytic: -0.002285, relative error: 3.162105e-05
# numerical: -2.121293 analytic: -2.121293, relative error: 1.639254e-09
# numerical: 0.613792 analytic: 0.613792, relative error: 3.795313e-08
# numerical: -3.728849 analytic: -3.728849, relative error: 8.462139e-09
# numerical: -2.199112 analytic: -2.199112, relative error: 3.435701e-08
# numerical: -0.726390 analytic: -0.726390, relative error: 2.256804e-08
# numerical: 0.813817 analytic: 0.813817, relative error: 7.591342e-08
# numerical: 1.295864 analytic: 1.295864, relative error: 2.251618e-08
# numerical: 0.067850 analytic: 0.067850, relative error: 2.885516e-07
# numerical: -1.337450 analytic: -1.337450, relative error: 1.568194e-08

# %%
# Теперь, когда у нас есть наивная реализация функции потери softmax и ее градиента,
# реализуйте векторную версию функции softmax_loss_vectorized.
# Две версии должны вычислять одни и те же результаты, но векторизованная версия должна быть
# намного быстрее.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# Как и для SVM, мы используем норму Фробениуса для сравнения двух версий
# вычисления градиента.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.302587e+00 computed in 0.079023s
# vectorized loss: 2.302587e+00 computed in 0.003982s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Используйте валидационное множество для выбора гиперпараметров (коэффициента регуляризации и
# скорости обучения). Вы должны экспериментировать с различными значениями скорости обучения
# и коэффициента регуляризации; если вы будете аккуратны, то должны 
# получить точность классификации более 0,35 на валидационном множестве.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [2e-5, 4e-5, 7e-5, 2e-6, 4e-6, 7e-6,2e-7, 4e-7, 7e-7]
regularization_strengths = [2e2, 5e2, 7e2,2e3,5e3, 7e3, 1e4, 15e3, 2e4, 3e4]

################################################################################
# ЗАДАНИЕ:                                                                     #
# Используйте валидационное множество, чтобы выбрать скорость обучения         #
# и коэффициент регуляризации. Это аналогично процессу валидации, который вы   #
# реализовали для SVM; сохраните лучший обученный softmax классификатор в      #
# best_softmax.                                                                #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate=lr, reg=reg, num_iters=1000, verbose=False)
        y_train_pred = softmax.predict(X_train)
        train_accuracy = np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_accuracy = np.mean(y_val == y_val_pred)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax
        
        print('val accuracy: %f' % (val_accuracy, ))
        results[(lr, reg)] = (train_accuracy, val_accuracy)
################################################################################
#                              КОНЕЦ ВАШЕГО КОДА                               #
################################################################################
    
# Вывод результатов
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# val accuracy: 0.237000
# val accuracy: 0.254000
# val accuracy: 0.296000
# val accuracy: 0.198000
# val accuracy: 0.246000
# val accuracy: 0.168000
# val accuracy: 0.164000
# val accuracy: 0.168000
# val accuracy: 0.178000
# val accuracy: 0.132000
# val accuracy: 0.230000
# val accuracy: 0.275000
# val accuracy: 0.228000
# val accuracy: 0.204000
# val accuracy: 0.207000
# val accuracy: 0.182000
# val accuracy: 0.152000
# val accuracy: 0.140000
# val accuracy: 0.131000
# val accuracy: 0.054000
# val accuracy: 0.241000
# val accuracy: 0.255000
# val accuracy: 0.267000
# val accuracy: 0.214000
# val accuracy: 0.114000
# val accuracy: 0.095000
# val accuracy: 0.121000
# val accuracy: 0.108000
# val accuracy: 0.097000
# val accuracy: 0.087000
# val accuracy: 0.362000
# val accuracy: 0.392000
# val accuracy: 0.396000
# val accuracy: 0.390000
# val accuracy: 0.380000
# val accuracy: 0.385000
# val accuracy: 0.372000
# val accuracy: 0.363000
# val accuracy: 0.328000
# val accuracy: 0.352000
# val accuracy: 0.353000
# val accuracy: 0.386000
# val accuracy: 0.426000
# val accuracy: 0.347000
# val accuracy: 0.360000
# val accuracy: 0.335000
# val accuracy: 0.319000
# val accuracy: 0.294000
# val accuracy: 0.322000
# val accuracy: 0.301000
# val accuracy: 0.359000
# val accuracy: 0.320000
# val accuracy: 0.352000
# val accuracy: 0.252000
# val accuracy: 0.286000
# val accuracy: 0.256000
# val accuracy: 0.207000
# val accuracy: 0.207000
# val accuracy: 0.227000
# val accuracy: 0.183000
# val accuracy: 0.272000
# val accuracy: 0.273000
# val accuracy: 0.255000
# val accuracy: 0.292000
# val accuracy: 0.340000
# val accuracy: 0.341000
# val accuracy: 0.363000
# val accuracy: 0.378000
# val accuracy: 0.370000
# val accuracy: 0.359000
# val accuracy: 0.280000
# val accuracy: 0.307000
# val accuracy: 0.322000
# val accuracy: 0.333000
# val accuracy: 0.390000
# val accuracy: 0.393000
# val accuracy: 0.397000
# val accuracy: 0.375000
# val accuracy: 0.359000
# val accuracy: 0.351000
# val accuracy: 0.296000
# val accuracy: 0.336000
# val accuracy: 0.341000
# val accuracy: 0.407000
# val accuracy: 0.378000
# val accuracy: 0.389000
# val accuracy: 0.386000
# val accuracy: 0.375000
# val accuracy: 0.366000
# val accuracy: 0.347000
# lr 2.000000e-07 reg 2.000000e+02 train accuracy: 0.265082 val accuracy: 0.272000
# lr 2.000000e-07 reg 5.000000e+02 train accuracy: 0.262816 val accuracy: 0.273000
# lr 2.000000e-07 reg 7.000000e+02 train accuracy: 0.262082 val accuracy: 0.255000
# lr 2.000000e-07 reg 2.000000e+03 train accuracy: 0.277918 val accuracy: 0.292000
# lr 2.000000e-07 reg 5.000000e+03 train accuracy: 0.323122 val accuracy: 0.340000
# lr 2.000000e-07 reg 7.000000e+03 train accuracy: 0.337306 val accuracy: 0.341000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.356735 val accuracy: 0.363000
# lr 2.000000e-07 reg 1.500000e+04 train accuracy: 0.361980 val accuracy: 0.378000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.355714 val accuracy: 0.370000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.344000 val accuracy: 0.359000
# lr 4.000000e-07 reg 2.000000e+02 train accuracy: 0.300306 val accuracy: 0.280000
# lr 4.000000e-07 reg 5.000000e+02 train accuracy: 0.303531 val accuracy: 0.307000
# lr 4.000000e-07 reg 7.000000e+02 train accuracy: 0.309143 val accuracy: 0.322000
# lr 4.000000e-07 reg 2.000000e+03 train accuracy: 0.338245 val accuracy: 0.333000
# lr 4.000000e-07 reg 5.000000e+03 train accuracy: 0.377735 val accuracy: 0.390000
# lr 4.000000e-07 reg 7.000000e+03 train accuracy: 0.375878 val accuracy: 0.393000
# lr 4.000000e-07 reg 1.000000e+04 train accuracy: 0.374429 val accuracy: 0.397000
# lr 4.000000e-07 reg 1.500000e+04 train accuracy: 0.362510 val accuracy: 0.375000
# lr 4.000000e-07 reg 2.000000e+04 train accuracy: 0.351735 val accuracy: 0.359000
# lr 4.000000e-07 reg 3.000000e+04 train accuracy: 0.347898 val accuracy: 0.351000
# lr 7.000000e-07 reg 2.000000e+02 train accuracy: 0.323694 val accuracy: 0.296000
# lr 7.000000e-07 reg 5.000000e+02 train accuracy: 0.338184 val accuracy: 0.336000
# lr 7.000000e-07 reg 7.000000e+02 train accuracy: 0.345000 val accuracy: 0.341000
# lr 7.000000e-07 reg 2.000000e+03 train accuracy: 0.383531 val accuracy: 0.407000
# lr 7.000000e-07 reg 5.000000e+03 train accuracy: 0.379857 val accuracy: 0.378000
# lr 7.000000e-07 reg 7.000000e+03 train accuracy: 0.378020 val accuracy: 0.389000
# lr 7.000000e-07 reg 1.000000e+04 train accuracy: 0.368327 val accuracy: 0.386000
# lr 7.000000e-07 reg 1.500000e+04 train accuracy: 0.361755 val accuracy: 0.375000
# lr 7.000000e-07 reg 2.000000e+04 train accuracy: 0.360653 val accuracy: 0.366000
# lr 7.000000e-07 reg 3.000000e+04 train accuracy: 0.334082 val accuracy: 0.347000
# lr 2.000000e-06 reg 2.000000e+02 train accuracy: 0.373918 val accuracy: 0.362000
# lr 2.000000e-06 reg 5.000000e+02 train accuracy: 0.393898 val accuracy: 0.392000
# lr 2.000000e-06 reg 7.000000e+02 train accuracy: 0.406592 val accuracy: 0.396000
# lr 2.000000e-06 reg 2.000000e+03 train accuracy: 0.393041 val accuracy: 0.390000
# lr 2.000000e-06 reg 5.000000e+03 train accuracy: 0.377510 val accuracy: 0.380000
# lr 2.000000e-06 reg 7.000000e+03 train accuracy: 0.371816 val accuracy: 0.385000
# lr 2.000000e-06 reg 1.000000e+04 train accuracy: 0.361898 val accuracy: 0.372000
# lr 2.000000e-06 reg 1.500000e+04 train accuracy: 0.347061 val accuracy: 0.363000
# lr 2.000000e-06 reg 2.000000e+04 train accuracy: 0.338102 val accuracy: 0.328000
# lr 2.000000e-06 reg 3.000000e+04 train accuracy: 0.336571 val accuracy: 0.352000
# lr 4.000000e-06 reg 2.000000e+02 train accuracy: 0.370306 val accuracy: 0.353000
# lr 4.000000e-06 reg 5.000000e+02 train accuracy: 0.383918 val accuracy: 0.386000
# lr 4.000000e-06 reg 7.000000e+02 train accuracy: 0.400265 val accuracy: 0.426000
# lr 4.000000e-06 reg 2.000000e+03 train accuracy: 0.355694 val accuracy: 0.347000
# lr 4.000000e-06 reg 5.000000e+03 train accuracy: 0.358306 val accuracy: 0.360000
# lr 4.000000e-06 reg 7.000000e+03 train accuracy: 0.327082 val accuracy: 0.335000
# lr 4.000000e-06 reg 1.000000e+04 train accuracy: 0.326224 val accuracy: 0.319000
# lr 4.000000e-06 reg 1.500000e+04 train accuracy: 0.305592 val accuracy: 0.294000
# lr 4.000000e-06 reg 2.000000e+04 train accuracy: 0.306755 val accuracy: 0.322000
# lr 4.000000e-06 reg 3.000000e+04 train accuracy: 0.298714 val accuracy: 0.301000
# lr 7.000000e-06 reg 2.000000e+02 train accuracy: 0.363898 val accuracy: 0.359000
# lr 7.000000e-06 reg 5.000000e+02 train accuracy: 0.330673 val accuracy: 0.320000
# lr 7.000000e-06 reg 7.000000e+02 train accuracy: 0.346388 val accuracy: 0.352000
# lr 7.000000e-06 reg 2.000000e+03 train accuracy: 0.258837 val accuracy: 0.252000
# lr 7.000000e-06 reg 5.000000e+03 train accuracy: 0.278531 val accuracy: 0.286000
# lr 7.000000e-06 reg 7.000000e+03 train accuracy: 0.256959 val accuracy: 0.256000
# lr 7.000000e-06 reg 1.000000e+04 train accuracy: 0.207265 val accuracy: 0.207000
# lr 7.000000e-06 reg 1.500000e+04 train accuracy: 0.196878 val accuracy: 0.207000
# lr 7.000000e-06 reg 2.000000e+04 train accuracy: 0.226633 val accuracy: 0.227000
# lr 7.000000e-06 reg 3.000000e+04 train accuracy: 0.163816 val accuracy: 0.183000
# lr 2.000000e-05 reg 2.000000e+02 train accuracy: 0.233469 val accuracy: 0.237000
# lr 2.000000e-05 reg 5.000000e+02 train accuracy: 0.239837 val accuracy: 0.254000
# lr 2.000000e-05 reg 7.000000e+02 train accuracy: 0.281571 val accuracy: 0.296000
# lr 2.000000e-05 reg 2.000000e+03 train accuracy: 0.183857 val accuracy: 0.198000
# lr 2.000000e-05 reg 5.000000e+03 train accuracy: 0.251163 val accuracy: 0.246000
# lr 2.000000e-05 reg 7.000000e+03 train accuracy: 0.176694 val accuracy: 0.168000
# lr 2.000000e-05 reg 1.000000e+04 train accuracy: 0.153102 val accuracy: 0.164000
# lr 2.000000e-05 reg 1.500000e+04 train accuracy: 0.168490 val accuracy: 0.168000
# lr 2.000000e-05 reg 2.000000e+04 train accuracy: 0.159878 val accuracy: 0.178000
# lr 2.000000e-05 reg 3.000000e+04 train accuracy: 0.137020 val accuracy: 0.132000
# lr 4.000000e-05 reg 2.000000e+02 train accuracy: 0.218367 val accuracy: 0.230000
# lr 4.000000e-05 reg 5.000000e+02 train accuracy: 0.261265 val accuracy: 0.275000
# lr 4.000000e-05 reg 7.000000e+02 train accuracy: 0.233735 val accuracy: 0.228000
# lr 4.000000e-05 reg 2.000000e+03 train accuracy: 0.201959 val accuracy: 0.204000
# lr 4.000000e-05 reg 5.000000e+03 train accuracy: 0.202612 val accuracy: 0.207000
# lr 4.000000e-05 reg 7.000000e+03 train accuracy: 0.167816 val accuracy: 0.182000
# lr 4.000000e-05 reg 1.000000e+04 train accuracy: 0.139714 val accuracy: 0.152000
# lr 4.000000e-05 reg 1.500000e+04 train accuracy: 0.147531 val accuracy: 0.140000
# lr 4.000000e-05 reg 2.000000e+04 train accuracy: 0.126673 val accuracy: 0.131000
# lr 4.000000e-05 reg 3.000000e+04 train accuracy: 0.076878 val accuracy: 0.054000
# lr 7.000000e-05 reg 2.000000e+02 train accuracy: 0.220898 val accuracy: 0.241000
# lr 7.000000e-05 reg 5.000000e+02 train accuracy: 0.273163 val accuracy: 0.255000
# lr 7.000000e-05 reg 7.000000e+02 train accuracy: 0.234531 val accuracy: 0.267000
# lr 7.000000e-05 reg 2.000000e+03 train accuracy: 0.193367 val accuracy: 0.214000
# lr 7.000000e-05 reg 5.000000e+03 train accuracy: 0.122633 val accuracy: 0.114000
# lr 7.000000e-05 reg 7.000000e+03 train accuracy: 0.107061 val accuracy: 0.095000
# lr 7.000000e-05 reg 1.000000e+04 train accuracy: 0.118429 val accuracy: 0.121000
# lr 7.000000e-05 reg 1.500000e+04 train accuracy: 0.104204 val accuracy: 0.108000
# lr 7.000000e-05 reg 2.000000e+04 train accuracy: 0.113061 val accuracy: 0.097000
# lr 7.000000e-05 reg 3.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.426000

# %%
# Оценка лучшего классификатора на тестовом множестве
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.374000

# %% [markdown]
# **Вопрос** - *Да или нет*
#
# Можно добавить новую точку данных в обучающее множество и это оставит SVM потери без изменений, но это не верно применительно к потерям, вычисляемым Softmax классификатором.
#
# *Ваш ответ*:
#
# *Ваши объяснения*:

# %%
# Визуализация обученных весов для каждого класса.
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
